# %%
#Get the data
import pandas
data = pandas.read_csv('data/school.csv')
data
# Out:
#        ids        bday  enrolldate   expgradate  Rank  \
# 0    43783   3/22/1995         NaN          NaN   NaN
# 1    20278    1/1/1995         NaN          NaN   NaN
# 2    20389  12/31/1994         NaN          NaN   NaN
# 3    22820   12/1/1994         NaN          NaN   NaN
# 4    24559  11/10/1994         NaN          NaN   NaN
# ..     ...         ...         ...          ...   ...
# 430  34021   7/18/1987  1-Aug-2011  08-May-2017   4.0
# 431  40697   4/29/1987  1-Aug-2011  09-May-2016   4.0
# 432  34272         NaN  1-Aug-2011  09-May-2016   4.0
# 433  33628         NaN  1-Aug-2011  08-May-2017   4.0
# 434  39298         NaN  1-Aug-2011  08-May-2017   4.0
#
#                        Major  Gender  Athlete  Height  Weight  ...  English  \
# 0                        NaN     0.0        0   72.35     NaN  ...    88.24
# 1                 Philosophy     0.0        0   70.66  179.20  ...    89.45
# 2                        NaN     0.0        0   70.68  198.52  ...    96.73
# ...

# %%
# Know the empties
data.isnull().sum()
# Out:
# ids               0
# bday              8
# enrolldate       29
# expgradate       29
# Rank             29
# Major           159
# Gender            9
# Athlete           0
# Height           27
# Weight           59
# Smoking          24
# Sprint           61
# MileMinDur       43
# English          26
# Reading          10
# Math             13
# Writing          31
# State            27
# LiveOnCampus     21
# HowCommute      188
# CommuteTime     188
# SleepTime        32
# StudyTime        42
# dtype: int64

# %%
# One sample T test
# Fill in the empties
mean_math = data['Math'].mean()
data['Math'].fillna(mean_math,inplace=True)

# %%
#Get the total mean
mean_population = data['Math'].mean()
mean_population
# Out:
# 65.46800947867298

# %%
#Get the sample
math_sample = data['Math'].sample(30)

# %%
#Now we test the sample
from scipy.stats import ttest_1samp
statistics, pvalue = ttest_1samp(a=math_sample,popmean=mean_population)
print(pvalue)
if pvalue>0.05:
    print('Accept the Null Hypothesis')
    print("Reject the Alternative...")
else:
    print("Accept the Alternative")
    print('Reject the Null Hypothesis')
# Out:
# 0.7176231418224541
# Accept the Null Hypothesis
# Reject the Alternative...
